# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nx =41;
dx = 2/(nx -1)
nt = 25
dt = 0.025
c = 1

# %%
u = np.ones(nx)
u[int(0.5/dx):int(1/dx)+1] = 2
plt.plot(np.linspace(0,2,nx),u,'r',lw=3,label = 'init')

# %%
un = np.ones(nx)
for n in range(nt):
    un = u.copy()
    for i in range(1,nx):
        u[i] = un[i] - c* dt / dx * (un[i] - un[i-1])
plt.plot(np.linspace(0,2,nx),u,'b',lw=3,label = 'current')
plt.legend()
plt.show()

# %%
un = np.ones(nx)
for n in range(nt):
    un = u.copy()
    for i in range(1,nx-1):
        u[i] = un[i] - c * dt / dx * (un[i+1] - un[i])
plt.plot(np.linspace(0,2,nx),u,'b',lw=3,label = 'current')
plt.legend()
plt.show()

# %%
un = np.ones(nx)
for n in range(nt):
    un = u.copy()
    for i in range(1,nx-1):
        u[i] = un[i] - un[i] * dt / dx * (un[i] - un[i-1])
plt.plot(np.linspace(0,2,nx),u,'b',lw=3,label = 'current')
plt.legend()
plt.show()
# Out:
# C:\Users\23984\AppData\Local\Temp\ipykernel_14760\3953984500.py:5: RuntimeWarning: overflow encountered in scalar multiply
#   u[i] = un[i] - un[i] * dt / dx * (un[i] - un[i-1])
# C:\Users\23984\AppData\Local\Temp\ipykernel_14760\3953984500.py:5: RuntimeWarning: invalid value encountered in scalar subtract
#   u[i] = un[i] - un[i] * dt / dx * (un[i] - un[i-1])
